# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("summer.csv")
df.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %% [markdown]
#                        1. In how many cities Summer Olympics is held so far?

# %%
no_of_cities = len(df["City"].unique())
print("There are total",no_of_cities,"cities where Summer Olympics was held so far.")
# Out:
# There are total 22 cities where Summer Olympics was held so far.

# %% [markdown]
#                 2. Which sport is having most number of Gold Medals so far? (Top 5)¶

# %%
Gold_data = df[df["Medal"] == "Gold"]
data = []

for sport in Gold_data["Sport"].unique():
    data.append([sport, len(Gold_data[Gold_data["Sport"] == sport])])
    
Gold = pd.DataFrame(data, columns = ["sport","Num_of_Gold_Medals"]) 
Gold = Gold.sort_values(by = "Num_of_Gold_Medals", ascending = False).head()

print("Top 5 Sports having most number of Gold Medals so far \n")
print(Gold)
print("\n")

Gold.plot(x = "sport", y = "Num_of_Gold_Medals", kind = "bar", figsize = (10,5), title = "Most Gold Medals won on sports")
# Out:
# Top 5 Sports having most number of Gold Medals so far
#
#          sport  Num_of_Gold_Medals
# 0     Aquatics                1421
# 1    Athletics                1215
# 17      Rowing                 890
# 4   Gymnastics                 820
# 3      Fencing                 552
# <AxesSubplot:title={'center':'Most Gold Medals won on sports'}, xlabel='sport'>

# %% [markdown]
#                       3. Which sport is having most number of medals so far? (Top 5)

# %%
data = []

for sport in df["Sport"].unique():
    data.append([sport, len(df[df["Sport"] == sport])])
    
Medal = pd.DataFrame(data, columns = ["Sport","Num_Medal"])
Medal = Medal.sort_values(by = "Num_Medal", ascending = False).head()

print("Top 5 Sports having most numbers of medals so far.\n")
print(Medal)
print("\n")

Medal.plot(x = "Sport", y = "Num_Medal", kind = "bar", color = "green", ylabel = "Number of Medals ", figsize = (10,5), title = "Most Medals Won in Sports(Tpo 5)")
# Out:
# Top 5 Sports having most numbers of medals so far.
#
#          Sport  Num_Medal
# 0     Aquatics       4170
# 1    Athletics       3638
# 17      Rowing       2667
# 4   Gymnastics       2307
# 3      Fencing       1613
# <AxesSubplot:title={'center':'Most Medals Won in Sports(Tpo 5)'}, xlabel='Sport', ylabel='Number of Medals '>

# %% [markdown]
#                       4. Which player has won most number of medals? (Top 5)

# %%
data = []

for athlete in df['Athlete'].unique():
    data.append([athlete , len(df[df['Athlete']  == athlete])])
    
athlete = pd.DataFrame(data, columns=['Athlete','Num_Medal'])                  
athlete = athlete.sort_values(by = 'Num_Medal', ascending = False).head()  

print('Top 5 Athlete whose won most medals \n')
print(athlete)                                                                  
print('\n')

athlete.plot(x = 'Athlete' , y = 'Num_Medal', ylabel= 'Number of Medal', kind = 'bar', color = "red", figsize = (10,5), title = 'Most Medal won by Athlete (Top 5)')
# Out:
# Top 5 Athlete whose won most medals
#
#                     Athlete  Num_Medal
# 18640       PHELPS, Michael         22
# 7197       LATYNINA, Larisa         18
# 9948     ANDRIANOV, Nikolay         15
# 6591           ONO, Takashi         13
# 5103   MANGIAROTTI, Edoardo         13
# <AxesSubplot:title={'center':'Most Medal won by Athlete (Top 5)'}, xlabel='Athlete', ylabel='Number of Medal'>

# %% [markdown]
#                    5. Which player has won most number Gold Medals of medals? (Top 5)

# %%
Gold_data = df[df["Medal"] == "Gold"]
data = []

for athlete in Gold_data['Athlete'].unique():
    data.append([athlete , len(Gold_data[Gold_data['Athlete']  == athlete])])
    
athlete = pd.DataFrame(data, columns=['Athlete','Num_Medal'])                  
athlete = athlete.sort_values(by = 'Num_Medal', ascending = False).head()  

print('Top 5 Athlete whose won most Gold medals \n')
print(athlete)                                                                  
print('\n')

athlete.plot(x = 'Athlete' , y = 'Num_Medal', ylabel= 'Number of Gold Medal', kind = 'bar', color = "green", figsize = (10,5), title = 'Most Gold Medal won by Athlete (Top 5)')
# Out:
# Top 5 Athlete whose won most Gold medals
#
#                Athlete  Num_Medal
# 6851   PHELPS, Michael         18
# 3320       SPITZ, Mark          9
# 2714  LATYNINA, Larisa          9
# 4630       LEWIS, Carl          9
# 907       NURMI, Paavo          9
# <AxesSubplot:title={'center':'Most Gold Medal won by Athlete (Top 5)'}, xlabel='Athlete', ylabel='Number of Gold Medal'>

# %% [markdown]
#  6.In which year India won first Gold Medal in Summer Olympics

# %%
gold_data= df[df["Medal"]=="Gold"]                                              
india_gold = gold_data[gold_data['Country'] == 'IND'].head(1)                   
                                                                                
year = int(india_gold['Year'])                                                  
print('India Won its First Summer Olympic Medal in',year)
# Out:
# India Won its First Summer Olympic Medal in 1928

# %% [markdown]
#                   7. Which event is most popular in terms on number of players? (Top 5)

# %%
data = []

for event in df['Event'].unique():
    event_df = df[df['Event'] == event]                                             
    players = len(event_df['Athlete'].unique())                                   
    data.append([event , players])

player = pd.DataFrame(data, columns=['Event','Num_players'])                     
player = player.sort_values(by= 'Num_players', ascending= False).head()           

print('Top 5 Sport Events whose having most unique players \n')
print(player)                                                                   
print('\n')

player.plot(x = 'Event' , y = 'Num_players', ylabel= 'Number of players', kind = 'bar', figsize = (10,5), title = 'Number of Unique players in any sport events (Top 5)')
# Out:
# Top 5 Sport Events whose having most unique players
#
#                         Event  Num_players
# 80                   Football         1357
# 176                    Hockey         1154
# 138          Team Competition          975
# 83   Eight With Coxswain (8+)          828
# 327                Basketball          814
# <AxesSubplot:title={'center':'Number of Unique players in any sport events (Top 5)'}, xlabel='Event', ylabel='Number of players'>

# %% [markdown]
#                      8. Which sport is having most female Gold Medalists? (Top 5)

# %%
female_data= df[df['Gender'] == "Women"]                                        
gold_data= female_data[female_data["Medal"] == "Gold"]  

data=[]

for sport in gold_data['Sport'].unique():
    data.append([sport , len(gold_data[gold_data['Sport']  == sport])])
    
medal = pd.DataFrame(data, columns=['Sport','Num_Medal'])                       
medal = medal.sort_values(by = 'Num_Medal', ascending = False).head()           

print('Top 5 sports having most medal won by Female \n')
print(medal)                                                                    
print('\n')

medal.plot(x = 'Sport' , y = 'Num_Medal', ylabel= 'Number of Medal', kind = 'bar', color = "red", figsize = (10,5), title = 'Most Medal won in Sports by Female (Top 5)')
# Out:
# Top 5 sports having most medal won by Female
#
#          Sport  Num_Medal
# 4     Aquatics        589
# 7    Athletics        389
# 8   Gymnastics        268
# 14      Rowing        217
# 11  Volleyball        166
# <AxesSubplot:title={'center':'Most Medal won in Sports by Female (Top 5)'}, xlabel='Sport', ylabel='Number of Medal'>
